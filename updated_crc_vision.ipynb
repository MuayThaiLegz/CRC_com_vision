# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
# Load the required packages
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import numpy as np

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout
from tensorflow.keras.models import Sequential

from sklearn.model_selection import train_test_split
from tqdm import tqdm

np.random.seed(1)
from pathlib import Path
from pandas.plotting import scatter_matrix
import hvplot.pandas
from tensorflow import keras
from pathlib import Path
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Load the required packages
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import os
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle           
import matplotlib.pyplot as plt             
import cv2                                 
import tensorflow as tf                
from tqdm import tqdm
# instatiatiing a small covnet
from tensorflow.keras.utils import to_categorical
# Importing all necessary libraries
from tensorflow.keras import layers
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
#from tensorflow.keras import backend as K
from tensorflow.keras import layers
from tensorflow.keras import models
# %matplotlib inline
import numpy as np
import datetime
import matplotlib as mpl 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
from sklearn.datasets import make_blobs
import pandas as pd
import seaborn as sn; sn.set(font_scale=1.4)

import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn import preprocessing
from sklearn import utils
pd.set_option('display.max_rows', 2000)
pd.set_option('display.max_columns', 2000)
pd.set_option('display.width', 1000)
# Using Haar Cascade model to detect faces in images.


from skimage.filters import threshold_otsu
from skimage.filters import threshold_local

from skimage.filters import sobel


# Import the modules from skimage
from skimage import data, color
from skimage.filters import try_all_threshold

# Import the modules from skimage
from skimage import data, color




# Import the module and the rotate and rescale functions
from skimage.transform import rotate, rescale

# %%
'''
original_data_KUBA = 'Kuba/Antique_Caucasian_Kuba.jpg'
img_original_data_KUBA = image.load_img(original_data_KUBA)
img_tensorKUBA = image.img_to_array(img_original_data_KUBA) / 250
img_tensorK = np.expand_dims(img_tensorKUBA, axis=0)
#display(img_tensorKUBA)
plt.imshow(img_tensorKUBA)
plt.show()


original_data_Antique_CaucasianKuba = 'Kuba/Antique_CaucasianKuba_Rug.jpg'
img_original_data_Anti_CauKuba = image.load_img(original_data_Antique_CaucasianKuba) 
img_tensorAnti_CauKuba = image.img_to_array(img_original_data_Anti_CauKuba) / 255
mg_tensor_CauKuba = np.expand_dims(img_original_data_Anti_CauKuba, axis=0)
plt.imshow(img_tensorAnti_CauKuba)
plt.show()
# Compile the model 
# The number of image categories
n_categories = 5

categories = np.array(['Gendje', 'Kazak', 'Kuba', 'Qashaqai','Shirvan'])

# Initialize ohe_labels as all zeros
ohe_labels = np.zeros((len(train_labels), n_categories))

# Loop over the labels
for ii in range(len(train_labels)):
    # Find the location of this label in the categories variable
    jj = np.where(categories == train_labels[ii])
    # Set the corresponding zero to one
    ohe_labels[ii, jj] = 1
# Import the necessary components from Keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten

# Initialize the model object
model = Sequential()

# Add a convolutional layer
model.add(Conv2D(250, kernel_size=3, activation='relu', 
               input_shape=(225, 225, 3)))
model.add(Conv2D(50, kernel_size=3, activation='relu'))
# Flatten the output of the convolutional layer
model.add(Flatten())
# Add an output layer for the 3 categories
model.add(Dense(5, activation='softmax'))# Compile the model
model.compile(optimizer='adam', 
           loss='sparse_categorical_crossentropy', 
           metrics=['accuracy'])

model.evaluate(test_images, test_labels)

model.compile(optimizer="adam", 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# Fit the model on a training set
model.fit(train_images, train_labels, 
          validation_split=.20, 
          epochs=3, batch_size=4)

model.evaluate(test_images, test_labels, batch_size=5)


model = Sequential()

# Add a convolutional layer
model.add(Conv2D(250, kernel_size=3, activation='relu', 
               input_shape=(225, 225, 3),
               padding='same'))
model.add(Conv2D(50, kernel_size=3, activation='relu'))
# Flatten the output of the convolutional layer
model.add(Flatten())
# Add an output layer for the 3 categories
model.add(Dense(5, activation='softmax'))

# Compile model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# Fit the model to training data 
model.fit(train_images, train_labels, 
          validation_split=0.2, 
          epochs=3, batch_size=10)

# Evaluate the model on test data
model.evaluate(test_images, test_labels)

'''
# Out:
# '\noriginal_data_KUBA = \'Kuba/Antique_Caucasian_Kuba.jpg\'\nimg_original_data_KUBA = image.load_img(original_data_KUBA)\nimg_tensorKUBA = image.img_to_array(img_original_data_KUBA) / 250\nimg_tensorK = np.expand_dims(img_tensorKUBA, axis=0)\n#display(img_tensorKUBA)\nplt.imshow(img_tensorKUBA)\nplt.show()\n\n\noriginal_data_Antique_CaucasianKuba = \'Kuba/Antique_CaucasianKuba_Rug.jpg\'\nimg_original_data_Anti_CauKuba = image.load_img(original_data_Antique_CaucasianKuba) \nimg_tensorAnti_CauKuba = image.img_to_array(img_original_data_Anti_CauKuba) / 255\nmg_tensor_CauKuba = np.expand_dims(img_original_data_Anti_CauKuba, axis=0)\nplt.imshow(img_tensorAnti_CauKuba)\nplt.show()\n# Compile the model \n# The number of image categories\nn_categories = 5\n\ncategories = np.array([\'Gendje\', \'Kazak\', \'Kuba\', \'Qashaqai\',\'Shirvan\'])\n\n# Initialize ohe_labels as all zeros\nohe_labels = np.zeros((len(train_labels), n_categories))\n\n# Loop over the labels\nfor ii in range(len(train_lab
# ...

# %%
from abc import ABCMeta, abstractmethod

class Vector(metaclass=ABCMeta):
    @abstractmethod
    def scale(self, scalar):
        pass
    @abstractmethod
    def add(self, other):
        pass
    
    def __add__(self, other):
        return self.add(other)
    def __mul__(self, scalar):
        return self.scale(scalar)
    def __rmul__(self,scalar):
        return self.scale(scalar)
    def subtract(self, other):
        return self.add(-1 * other)
    def __sub__(self, other):
        return self.subtract(other)
    
class Vec2(Vector):
    def __init__(self,x,y):
        self.x = x
        self.y = y
    def add(self,other):
        return Vec2(self.x + other.x, self.y + other.y)
    def scale(self,scalar):
        return Vec2(scalar * self.x, scalar * self.y)
    def __eq__(self,other):
        return self.x == other.x and self.y == other.y
    def __repr__(self):
        return "Vec2({},{})".format(self.x, self.y)
    
    from PIL import Image


class ImageVector(Vector):
    size = (300,300)
    def __init__(self, input):
        try:
            img = Image.open(input).resize(ImageVector.size)
            self.pixels = img.getdata()
        except:
            self.pixels = input
    
    def image(self):
        img = Image.new('RGB', ImageVector.size)
        img.putdata([(int(r), int(g),  int(b)) for (r,g,b) in self.pixels])
        return img
    
    def add(self, img2):
        return ImageVector([(r1+r2,g1+g2,b1+b2) for ((r1,g1,b1),(r2,g2,b2))
                            in zip(self.pixels, img2.pixels)])
    
    def scale(self,scalar):
        return ImageVector([(scalar*r, scalar*g, scalar*b)
                            for (r,g,b) in self.pixels])
        
    @classmethod
    def zero(cls):
        total_pixels = cls.size[0] * cls.size[1]
        return ImageVector([(0,0,0) for _ in range(0, total_pixels)])
    
    def _repr_png_(self): #8
        return self.image()._repr_png_()
    
    

def show_image(image, title='Image'):
    plt.imshow(image)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
Pinwheel_Kazak = image.load_img("Pinwheel_Kazak.jpg") 
tensor_Pinwheel_Kazak = image.img_to_array(Pinwheel_Kazak) / 255

gray_Pinwheel_Kazak = color.rgb2gray(tensor_Pinwheel_Kazak)


# Obtain the optimal threshold value with otsu
thresh = threshold_otsu(gray_Pinwheel_Kazak)

# Apply thresholding to the image
binary = gray_Pinwheel_Kazak > thresh

# Obtain the optimal otsu global thresh value
global_thresh = threshold_local(binary)


# Obtain the binary image by applying global thresholding
binary_global = gray_Pinwheel_Kazak > global_thresh

edge_sobel = sobel(gray_Pinwheel_Kazak)



# Show the original image
show_image(tensor_Pinwheel_Kazak, 'Original RGB image')

# Show the grayscale image
show_image(gray_Pinwheel_Kazak, 'Grayscale image')

show_image(edge_sobel, "Edges with Sobel")

# Show the image
show_image(binary, 'Binary image')

# Show the binary image obtained
show_image(binary_global, 'Global thresholding')

# %%
# Use the try all method on the resulting grayscale image
fig, ax = try_all_threshold(gray_Pinwheel_Kazak)

# Show the resulting plots
plt.show()
# Out:
# skimage.filters.thresholding.threshold_isodata
# skimage.filters.thresholding.threshold_li
# skimage.filters.thresholding.threshold_mean
# skimage.filters.thresholding.threshold_minimum
# skimage.filters.thresholding.threshold_otsu
# skimage.filters.thresholding.threshold_triangle
# skimage.filters.thresholding.threshold_yen

# %%
# Import the module and the rotate and rescale functions
from skimage.transform import rotate, rescale

# Rotate the image 90 degrees clockwise 
rotated_image = rotate(tensor_Pinwheel_Kazak, -90)

# Rescale with anti aliasing``
rescaled_with_aa = rescale(rotated_image, 1/3, anti_aliasing=True, multichannel=True)

# Rescale without anti aliasing
rescaled_without_aa =  rescale(rotated_image, 1/2, anti_aliasing=False, multichannel=True)

rescaled_gray_Pinwheel_Kazak = cv2.cvtColor(rescaled_without_aa, cv2.COLOR_RGB2Lab)

# Show the resulting images
show_image(rescaled_with_aa, "Transformed with anti aliasing")
show_image(rescaled_without_aa, "Transformed without anti aliasing")
show_image(rescaled_gray_Pinwheel_Kazak)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Import the slic function from segmentation module
from skimage.segmentation import slic

# Import the label2rgb function from color module
from skimage.color import label2rgb

from skimage import measure, data
# Obtain the segmentation with 400 regions
segments = slic(rescaled_with_aa, n_segments= 500)

# Put segments on top of original image to compare
segmented_image = label2rgb(segments, rescaled_with_aa, kind='avg')

# Show the segmented image
show_image(segmented_image, "Segmented image, 400 superpixels")
contours = measure.find_contours(gray_Pinwheel_Kazak, 0.8)

# %%
# Obtain the red channel
red_channel = rescaled_with_aa[:,:, 0]

# Plot the red histogram with bins in a range of 256
plt.hist(red_channel.ravel(), bins=25)

# Set title and show
plt.title('Red Histogram')
plt.show()

# %%
# Obtain the optimal threshold value with otsu
thresh = threshold_otsu(rescaled_with_aa)

# Apply thresholding to the image
binary = rescaled_with_aa > thresh

# Obtain the optimal otsu global thresh value
global_thresh = threshold_local(rescaled_with_aa)

# Obtain the binary image by applying global thresholding
binary_global = rescaled_with_aa > global_thresh

edge_sobel = sobel(rescaled_with_aa)

# %%
# Show the original image
show_image(rescaled_with_aa, 'Original RGB image')

show_image(edge_sobel, "Edges with Sobel")

# %%
import cv2

ret, custom_thresh_im = cv2.threshold(gray_Pinwheel_Kazak, 127, 255, cv2.THRESH_BINARY)

im = cv2.imread('Kuba_R.jpg')

im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)

mean_thresh_im = cv2.adaptiveThreshold(im, 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY, 11, 2)

cv2.imwrite("Kuba_R.jpg", mean_thresh_im)


rugs = ['Antique_Caucasian_Pinwheel_Kazak_Rug.jpg', 'Antique_PersianCarpet_CaucasianKazak.jpg','cloud_bandAntique.jpg']
face_cascade = cv2.CascadeClassifier('input/haarcascade_frontalface_default.xml')

for filename in rugs:
    im = cv2.imread('input/' + filename)
    gray_im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    
    faces = face_cascade.detectMultiScale(gray_im, scaleFactor=1.2)
    
    for (x, y, w, h) in faces:
        cv2.rectangle(im, (x,  y), (x + w, y + h), (0, 255, 0), 2)
        
    cv2.imshow('%i face(s) found' % len(faces), im)
    cv2.waitKey(0)
    
print('Done..')
# Out:
# Done..

# %%
class_names = ['Gendje', 'Kazak', 'Kuba', 'Qashaqai','Shirvan']
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}

nb_classes = len(class_names)


IMAGE_SIZE = (225, 225)



def load_data():
    """
        Load the data:
            - 60 images to train the network.
            - 20 images to evaluate how accurately the network learned to classify images.
    """
    
    datasets = ['../pic_file/Data/Train_dir', '../pic_file/Data/Test_dir']
    output = []
    
    # Iterate through training and test sets
    for dataset in datasets:
        
        images = []
        labels = []
        
        print("Loading {}".format(dataset))
        
        # Iterate through each folder corresponding to a category
        for folder in os.listdir(dataset):
            label = class_names_label[folder]
            
            # Iterate through each image in our folder
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):
                
                # Get the path name of the image
                img_path = os.path.join(os.path.join(dataset, folder), file)
                
                # Open and resize the img
                image = cv2.imread(img_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, IMAGE_SIZE) 
                
                # Append the image and its corresponding label to the output
                images.append(image)
                labels.append(label)
                
        images = np.array(images, dtype = 'float32')
        labels = np.array(labels, dtype = 'int32')   
        
        output.append((images, labels))

    return output

# %%
(train_images, train_labels), (test_images, test_labels) = load_data()
# Out:
# Loading ../pic_file/Data/Train_dir
# ...
# 100%|██████████| 14/14 [00:00<00:00, 17.91it/s]
# Loading ../pic_file/Data/Test_dir
# ...
# 100%|██████████| 6/6 [00:00<00:00, 14.11it/s]

# %%
n_train = train_labels.shape[0]
n_test = test_labels.shape[0]

print ("Number of training examples: {}".format(n_train))
print ("Number of testing examples: {}".format(n_test))
print ("Each image is of size: {}".format(IMAGE_SIZE))
# Out:
# Number of training examples: 70
# Number of testing examples: 30
# Each image is of size: (225, 225)

# %%
# The number of image categories
n_categories = 5

categories = np.array(['Gendje', 'Kazak', 'Kuba', 'Qashaqai','Shirvan'])

# Initialize ohe_labels as all zeros
ohe_labels = np.zeros((len(train_labels), n_categories))

# Loop over the labels
for ii in range(len(train_labels)):
    # Find the location of this label in the categories variable
    jj = np.where(categories == train_labels[ii])
    # Set the corresponding zero to one
    ohe_labels[ii, jj] = 1

# %%
n_train = train_labels.shape[0]
n_test = test_labels.shape[0]

print ("Number of training examples: {}".format(n_train))
print ("Number of testing examples: {}".format(n_test))
print ("Each image is of size: {}".format(IMAGE_SIZE))
# Out:
# Number of training examples: 70
# Number of testing examples: 30
# Each image is of size: (225, 225)

# %%
import pandas as pd

_, train_counts = np.unique(train_labels, return_counts=True)
_, test_counts = np.unique(test_labels, return_counts=True)
pd.DataFrame({'train': train_counts,
                    'test': test_counts}, 
             index=class_names
            ).plot.bar()
plt.show()

# %%
plt.pie(train_counts,
        explode=(0, 0, 0, 0, 0) , 
        labels=class_names,
        autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %%
train_images = train_images / 225.0 
test_images = test_images / 225.0

# %%
def display_random_image(class_names, images, labels):
    """
        Display a random image from the images array and its correspond label from the labels array.
    """
    
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()
    
    
display_random_image(class_names, train_images, train_labels)

# %%
def plot_accuracy_loss(history):
    """
        Plot the accuracy and the loss during the training of the nn.
    """
    fig = plt.figure(figsize=(10,5))

    # Plot accuracy
    plt.subplot(221)
    plt.plot(history.history['accuracy'],'bo--', label = "acc")
    plt.plot(history.history['val_accuracy'], 'ro--', label = "val_acc")
    plt.title("train_acc vs val_acc")
    plt.ylabel("accuracy")
    plt.xlabel("epochs")
    plt.legend()

    # Plot loss function
    plt.subplot(222)
    plt.plot(history.history['loss'],'bo--', label = "loss")
    plt.plot(history.history['val_loss'], 'ro--', label = "val_loss")
    plt.title("train_loss vs val_loss")
    plt.ylabel("loss")
    plt.xlabel("epochs")

    plt.legend()
    plt.show()

# %%
    
modelz = tf.keras.Sequential([
    tf.keras.layers.Conv2D(62, (3, 3), activation = 'relu', input_shape = (225, 225, 3)), 
    tf.keras.layers.Conv2D(62, (3, 3), activation = 'relu'),
    
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(62, (3, 3), activation = 'relu'),
    tf.keras.layers.Conv2D(62, (3, 3), activation = 'relu'),
    
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation=tf.nn.relu),
    tf.keras.layers.Dense(5, activation=tf.nn.softmax)
])
modelz.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])
history = modelz.fit(train_images, train_labels, batch_size=128, epochs=12, validation_split = 0.2)
# Out:
# Epoch 1/12
# 1/1 [==============================] - 12s 12s/step - loss: 1.6101 - accuracy: 0.2500 - val_loss: 24.4752 - val_accuracy: 0.0000e+00
# Epoch 2/12
# 1/1 [==============================] - 10s 10s/step - loss: 5.5707 - accuracy: 0.2500 - val_loss: 9.3064 - val_accuracy: 0.0000e+00
# Epoch 3/12
# 1/1 [==============================] - 10s 10s/step - loss: 3.1064 - accuracy: 0.2500 - val_loss: 3.3998 - val_accuracy: 0.0000e+00
# Epoch 4/12
# 1/1 [==============================] - 11s 11s/step - loss: 1.4132 - accuracy: 0.4643 - val_loss: 2.9623 - val_accuracy: 0.0000e+00
# Epoch 5/12
# 1/1 [==============================] - 10s 10s/step - loss: 1.4707 - accuracy: 0.2500 - val_loss: 3.5730 - val_accuracy: 0.0000e+00
# Epoch 6/12
# 1/1 [==============================] - 10s 10s/step - loss: 1.3928 - accuracy: 0.2500 - val_loss: 5.4989 - val_accuracy: 0.0000e+00
# Epoch 7/12
# ...

# %%
plot_accuracy_loss(history)


test_loss = modelz.evaluate(test_images, test_labels)

predictions = modelz.predict(test_images)     # Vector of probabilities
pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability
# Out:
# 1/1 [==============================] - 1s 912ms/step - loss: 2.3058 - accuracy: 0.4000

# %%
def print_mislabeled_images(class_names, test_images, test_labels, pred_labels):
    """
        Print 25 examples of mislabeled images by the classifier, e.g when test_labels != pred_labels
    """
    BOO = (test_labels == pred_labels)
    mislabeled_indices = np.where(BOO == 1)
    mislabeled_images = test_images[mislabeled_indices]
    mislabeled_labels = pred_labels[mislabeled_indices]

    title = "Some examples of mislabeled images by the classifier:"
    display(class_names,  mislabeled_images, mislabeled_labels)

# %%
#print_mislabeled_images(class_names, test_images, test_labels, pred_labels)

# %%
CM = confusion_matrix(test_labels, pred_labels)
ax = plt.axes()
sn.heatmap(CM, annot=True, 
           annot_kws={"size": 10}, 
           xticklabels=class_names, 
           yticklabels=class_names, ax = ax)
ax.set_title('Confusion matrix')
plt.show()

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
from sklearn import decomposition

# %%
model = VGG16(weights='imagenet', include_top=False)
train_features = model.predict(train_images)
test_features = model.predict(test_images)

n_train, x, y, z = train_features.shape
n_test, x, y, z = test_features.shape
numFeatures = x * y * z

pca = decomposition.PCA(n_components = 5)

X = train_features.reshape((n_train, numFeatures))
pca.fit(X)

C = pca.transform(X) # Représentation des individus dans les nouveaux axe
C1 = C[:,0]
C2 = C[:,1]
C3 = C[:,2]
C4 = C[:,3]
C5 = C[:,4]

# %%
### Figures

plt.subplots(figsize=(10,10))

for i, class_name in enumerate(class_names):
    plt.scatter(C1[train_labels == i][:100], C2[train_labels == i][:100], label = class_name, alpha=0.4)
plt.legend()
plt.title("PCA Projection")
plt.show()

# %%
#Training on top of VGG
#Let's train a simple one-layer Neural Network on the features extracted from VGG.


model2 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape = (x, y, z)),
    tf.keras.layers.Dense(50, activation=tf.nn.relu),
    tf.keras.layers.Dense(6, activation=tf.nn.softmax)
])

model2.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

history2 = model2.fit(train_features, train_labels, batch_size=128, epochs=15, validation_split = 0.2)
# Out:
# Epoch 1/15
# 1/1 [==============================] - 1s 708ms/step - loss: 2.1297 - accuracy: 0.0893 - val_loss: 10.7240 - val_accuracy: 0.0000e+00
# Epoch 2/15
# 1/1 [==============================] - 0s 39ms/step - loss: 2.0599 - accuracy: 0.2500 - val_loss: 12.8338 - val_accuracy: 0.0000e+00
# Epoch 3/15
# 1/1 [==============================] - 0s 42ms/step - loss: 1.6831 - accuracy: 0.2679 - val_loss: 14.8985 - val_accuracy: 0.0000e+00
# Epoch 4/15
# 1/1 [==============================] - 0s 39ms/step - loss: 1.2975 - accuracy: 0.4643 - val_loss: 15.2192 - val_accuracy: 0.0000e+00
# Epoch 5/15
# 1/1 [==============================] - 0s 77ms/step - loss: 0.6104 - accuracy: 0.8750 - val_loss: 16.3554 - val_accuracy: 0.0000e+00
# Epoch 6/15
# 1/1 [==============================] - 0s 87ms/step - loss: 0.8225 - accuracy: 0.6786 - val_loss: 17.1045 - val_accuracy: 0.0000e+00
# Epoch 7/15
# ...

# %%
plot_accuracy_loss(history2)

# %%
test_loss = model2.evaluate(test_features, test_labels)
# Out:
# 1/1 [==============================] - 0s 35ms/step - loss: 4.9400 - accuracy: 0.6667

# %%
np.random.seed(seed=1997)
# Number of estimators
n_estimators = 10
# Proporition of samples to use to train each training
max_samples = 0.8

max_samples *= n_train
max_samples = int(max_samples)

# %%
models = list()
random = np.random.randint(50, 100, size = n_estimators)

for i in range(n_estimators):
    
    # Model
    model = tf.keras.Sequential([ tf.keras.layers.Flatten(input_shape = (x, y, z)),
                                # One layer with random size
                                    tf.keras.layers.Dense(random[i], activation=tf.nn.relu),
                                    tf.keras.layers.Dense(random[i], activation=tf.nn.relu),
                                    tf.keras.layers.Dense(5, activation=tf.nn.softmax)
                                ])
    
    model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])
    
    # Store model
    models.append(model)

# %%
histories = []

for i in range(n_estimators):
    # Train each model on a bag of the training data
    train_idx = np.random.choice(len(train_features), size = max_samples)
    histories.append(models[i].fit(train_features[train_idx], train_labels[train_idx], batch_size=128, epochs=15, validation_split = 0.2))
# Out:
# Epoch 1/15
# 1/1 [==============================] - 0s 110ms/step - loss: 1.1563 - accuracy: 0.6136 - val_loss: 1.0505 - val_accuracy: 0.5000
# Epoch 2/15
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9584 - accuracy: 0.7273 - val_loss: 1.3003 - val_accuracy: 0.4167
# Epoch 3/15
# 1/1 [==============================] - 0s 44ms/step - loss: 0.7461 - accuracy: 0.7500 - val_loss: 1.5687 - val_accuracy: 0.4167
# Epoch 4/15
# 1/1 [==============================] - 0s 42ms/step - loss: 0.7008 - accuracy: 0.7273 - val_loss: 1.5833 - val_accuracy: 0.5000
# Epoch 5/15
# 1/1 [==============================] - 0s 47ms/step - loss: 0.6083 - accuracy: 0.8409 - val_loss: 1.3889 - val_accuracy: 0.5833
# Epoch 6/15
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4862 - accuracy: 0.8409 - val_loss: 1.2466 - val_accuracy: 0.5833
# Epoch 7/15
# ...

# %%
predictions = []
for i in range(n_estimators):
    predictions.append(models[i].predict(test_features))
    
predictions = np.array(predictions)
predictions = predictions.sum(axis = 0)
pred_labels = predictions.argmax(axis=1)

# %%
from sklearn.metrics import accuracy_score
print("Accuracy : {}".format(accuracy_score(test_labels, pred_labels)))
# Out:
# Accuracy : 0.8333333333333334

# %%
from tensorflow.keras.models import Model

model = VGG16(weights='imagenet', include_top=False)
model = Model(inputs=model.inputs, outputs=model.layers[-5].output)

# %%
train_features = model.predict(train_images)
test_features = model.predict(test_images)

# %%
from tensorflow.keras.layers import Input, Dense, Conv2D, Activation , MaxPooling2D, Flatten

model2 = VGG16(weights='imagenet', include_top=False)

input_shape = model2.layers[-4].get_input_shape_at(0) # get the input shape of desired layer
layer_input = Input(shape = (14, 14, 512)) # a new input tensor to be able to feed the desired layer
# https://stackoverflow.com/questions/52800025/keras-give-input-to-intermediate-layer-and-get-final-output

x = layer_input
for layer in model2.layers[-4::1]:
    x = layer(x)
    
x = Conv2D(64, (3, 3), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Flatten()(x)
x = Dense(250,activation='relu')(x)
x = Dense(5,activation='softmax')(x)

# create the model
new_model = Model(layer_input, x)

# %%
new_model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
new_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_9 (InputLayer)        [(None, 14, 14, 512)]     0
#
#  block5_conv1 (Conv2D)       multiple                  2359808
#
#  block5_conv2 (Conv2D)       multiple                  2359808
#
#  block5_conv3 (Conv2D)       multiple                  2359808
#
#  block5_pool (MaxPooling2D)  multiple                  0
#
#  conv2d_17 (Conv2D)          (None, 5, 5, 64)          294976
#
#  max_pooling2d_9 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  flatten_16 (Flatten)        (None, 256)               0
#
#  dense_32 (Dense)            (None, 250)               64250
#
#  dense_33 (Dense)            (None, 5)                 1255
#
# ...
# Total params: 7,439,905
# Trainable params: 7,439,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
new_mod_history = new_model.fit(train_features, train_labels, batch_size=128, epochs=20, validation_split = 0.2)
# Out:
# Epoch 1/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.8729 - accuracy: 0.5714 - val_loss: 11.9542 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.8956 - accuracy: 0.5179 - val_loss: 13.1875 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.9337 - accuracy: 0.4821 - val_loss: 10.5051 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.9476 - accuracy: 0.6786 - val_loss: 10.8734 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.9964 - accuracy: 0.5893 - val_loss: 10.2557 - val_accuracy: 0.0000e+00
# Epoch 6/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.7244 - accuracy: 0.7321 - val_loss: 8.9514 - val_accuracy: 0.0000e+00
# Epoch 7/20
# ...

# %%
plot_accuracy_loss(new_mod_history)

# %%
from sklearn.metrics import accuracy_score

predictions = new_model.predict(test_features)    
pred_labels = np.argmax(predictions, axis = 1)
print("Accuracy : {}".format(accuracy_score(test_labels, pred_labels)))

display(test_loss = new_model.evaluate(test_features, test_labels))
# Out:
# Accuracy : 0.7666666666666667
# 1/1 [==============================] - 0s 248ms/step - loss: 6.3675 - accuracy: 0.7667

# %%
NM_predictions = new_model.predict(test_images)     # Vector of probabilities
NM_pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability

display_random_image(class_names, test_images, NM_pred_labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\JBarr\OneDrive\Documents\FinTech\crc_com_vision\pic_file\updated_crc_vision.ipynb Cell 50' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/JBarr/OneDrive/Documents/FinTech/crc_com_vision/pic_file/updated_crc_vision.ipynb#ch0000069?line=0'>1</a> NM_predictions = new_model.predict(test_images)     # Vector of probabilities
#       <a href='vscode-notebook-cell:/c%3A/Users/JBarr/OneDrive/Documents/FinTech/crc_com_vision/pic_file/updated_crc_vision.ipynb#ch0000069?line=1'>2</a> NM_pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability
#       <a href='vscode-notebook-cell:/c%3A/Users/JBarr/OneDrive/Documents/FinTech/crc_com_vision/pic_file/updated_crc_vision.ipynb#ch0000069?line=3'>4</a> display_random_image(class_names, test_images, NM_pred_labels)
#
# ...

# %%
def plot_accuracy_loss(history):
    """
        Plot the accuracy and the loss during the training of the nn.
    """
    fig = plt.figure(figsize=(10,5))

    # Plot accuracy
    plt.subplot(221)
    plt.plot(history.history['acc'],'bo--', label = "acc")
    plt.plot(history.history['val_acc'], 'ro--', label = "val_acc")
    plt.title("train_acc vs val_acc")
    plt.ylabel("accuracy")
    plt.xlabel("epochs")
    plt.legend()

    # Plot loss function
    plt.subplot(222)
    plt.plot(history.history['loss'],'bo--', label = "loss")
    plt.plot(history.history['val_loss'], 'ro--', label = "val_loss")
    plt.title("train_loss vs val_loss")
    plt.ylabel("loss")
    plt.xlabel("epochs")

    plt.legend()
    plt.show()

# %%
plot_accuracy_loss(history)

test_loss = modelz.evaluate(test_images, test_labels)


predictions = modelz.predict(test_images)     # Vector of probabilities
pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability

display_random_image(class_names, test_images, pred_labels)

def print_mislabeled_images(class_names, test_images, test_labels, pred_labels):
    """
        Print 25 examples of mislabeled images by the classifier, e.g when test_labels != pred_labels
    """
    BOO = (test_labels == pred_labels)
    mislabeled_indices = np.where(BOO == 0)
    mislabeled_images = test_images[mislabeled_indices]
    mislabeled_labels = pred_labels[mislabeled_indices]

    title = "Some examples of mislabeled images by the classifier:"
    display_examples(class_names,  mislabeled_images, mislabeled_labels)print_mislabeled_images(class_names, test_images, test_labels, pred_labels)

CM = confusion_matrix(test_labels, pred_labels)
ax = plt.axes()
sn.heatmap(CM, annot=True, 
           annot_kws={"size": 10}, 
           xticklabels=class_names, 
           yticklabels=class_names, ax = ax)
ax.set_title('Confusion matrix')
plt.show()

# %%
src_path_train = "data/Train_dir/"
src_path_test = "data/Test_dir/"


batch_size = 2

# %%
train_datagen = ImageDataGenerator(
        rescale=1 / 255.0,
        rotation_range=20,
        zoom_range=0.05,
        width_shift_range=0.05,
        height_shift_range=0.05,
        shear_range=0.05,
        horizontal_flip=True,
        fill_mode="nearest",
        validation_split=0.4)

val_datagen = ImageDataGenerator(rescale=1 / 255.0)

test_datagen = ImageDataGenerator(rescale=1 / 255.0)

# %%
train_generator = train_datagen.flow_from_directory(
    directory=src_path_train,
    target_size=(256, 256),
    color_mode="rgb",
    batch_size=5,
    class_mode="categorical",
    subset='training',
    shuffle=True,
    seed=42
)
# Out:
# Found 45 images belonging to 5 classes.

# %%
test_generator = test_datagen.flow_from_directory(
    directory=src_path_test,
    target_size=(256, 256),
    color_mode="rgb",
    batch_size=5,
    class_mode=None,
    shuffle=False,
    seed=42
)
# Out:
# Found 30 images belonging to 5 classes.

# %%
valid_generator = train_datagen.flow_from_directory(
    directory=src_path_train,
    target_size=(256, 256),
    color_mode="rgb",
    batch_size=5,
    class_mode="categorical",
    subset='validation',
    shuffle=True,
    seed=42
)
# Out:
# Found 25 images belonging to 5 classes.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(150, 3, activation = 'relu', input_shape = (256, 256, 3)), 
    tf.keras.layers.Conv2D(175, 3, activation='relu'),

    tf.keras.layers.MaxPooling2D(2),
    tf.keras.layers.Conv2D(200, 3, activation='relu'),

    tf.keras.layers.Conv2D(200, 3, activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2),
    tf.keras.layers.Flatten(),
    #tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(5, activation=tf.nn.softmax)
])

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit_generator(train_generator,
                    validation_data = train_generator,
                    steps_per_epoch = train_generator.n//train_generator.batch_size,
                    validation_steps = valid_generator.n//valid_generator.batch_size,
                    epochs=7)
# Out:
# Epoch 1/7
# 9/9 [==============================] - 39s 4s/step - loss: 1.7279 - accuracy: 0.2000 - val_loss: 1.6125 - val_accuracy: 0.2000
# Epoch 2/7
# 9/9 [==============================] - 39s 4s/step - loss: 1.6124 - accuracy: 0.2000 - val_loss: 1.8149 - val_accuracy: 0.2000
# Epoch 3/7
# 9/9 [==============================] - 37s 4s/step - loss: 1.6204 - accuracy: 0.2444 - val_loss: 1.6074 - val_accuracy: 0.2800
# Epoch 4/7
# 9/9 [==============================] - 37s 4s/step - loss: 1.6147 - accuracy: 0.2000 - val_loss: 1.6013 - val_accuracy: 0.2800
# Epoch 5/7
# 9/9 [==============================] - 38s 4s/step - loss: 1.6116 - accuracy: 0.2000 - val_loss: 1.6076 - val_accuracy: 0.1600
# Epoch 6/7
# 9/9 [==============================] - 38s 4s/step - loss: 1.6116 - accuracy: 0.2000 - val_loss: 1.6101 - val_accuracy: 0.1600
# Epoch 7/7
# 9/9 [==============================] - 38s 4s/step - loss: 1.6095 - accuracy: 0.2000 - val_loss: 1.6094 - val_accuracy: 0.1600

# %%
model.summary()

# %%
model.layers

# %%
hidden1 = model.layers[0]

# %%
weights,biases = hidden1.get_weights()

# %%
weights.shape

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 10)
plt.show()

# %%
model.evaluate_generator(valid_generator)

# %%
model.predict_generator(test_generator)

# %%
score = model.evaluate_generator(valid_generator)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %%
predict=model.predict_generator(valid_generator)
# predict the class label
y_classes = predict.argmax(axis=-1)
y_classes

# %%
Smodel = tf.keras.models.Sequential()
Smodel.add(layers.Conv2D(75, 7, activation='relu', padding= 'same' ,input_shape=[256, 256, 3])),

Smodel.add(layers.MaxPooling2D(2)),
Smodel.add(layers.Conv2D(128, 3, activation='relu')),
Smodel.add(layers.Conv2D(128, 2, activation='relu')),
Smodel.add(layers.MaxPooling2D(2)),
Smodel.add(layers.Flatten()),
Smodel.add(layers.Dense(100, activation='relu'))
Smodel.add(layers.Dropout(0.5)),
Smodel.add(layers.Dense(50, activation='relu'))
Smodel.add(layers.Dense(2, activation='softmax'))

# %%
from tensorflow.keras import optimizers

Smodel.compile(loss=['categorical_crossentropy'],
             optimizer='adam',
             metrics=['accuracy'])

# %%
hist = Smodel.fit_generator(train_generator,
                    validation_data = train_generator,
                    steps_per_epoch = train_generator.n//train_generator.batch_size,
                    validation_steps = valid_generator.n//valid_generator.batch_size,
                    epochs=20)

# %%
Smodel.summary()

# %%
hidden1 = Smodel.layers[0]

# %%
hidden1.name

# %%
#Smodel.get_layer('conv2d_70') is hidden1

# %%
weights,biases = hidden1.get_weights()
weights.shape

# %%
biases.shape

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 10)
plt.show()

# %%
Smodel.evaluate_generator(valid_generator)

# %%
Smodel.predict_generator(test_generator)

# %%
from PIL import Image

try:
    imgPath = 'Kuba/Antique_Caucasian_Kuba.jpg'
    img = Image.open(imgPath)
    print('The format of img is: ', img.format)
    print('The mode of img is: ', img.mode)
    print('The size of img is: ', img.size)
    print('The palette of img is: ', img.palette)
except FileNotFoundError:
    print('Provided image path is not found')
